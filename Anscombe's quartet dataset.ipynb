# %% [markdown]
# # Investigation of the Anscombe's quartet dataset

# %% [markdown]
# ## Background

# %% [markdown]
# The Anscombe quartet dataset comprised of four distinct datasets each with nearly identical statistical characteristics
# such as mean, correlation and regression lines.
#
# In 1973 Francis J. Anscombe puplished a paper named Graphs in Statistical Analysis that contained these four datasets. The paper
# shows that even though the summary statistics are almost identical, but when plotted the graphs show that the datasets
# are actually quite different, giving the user a very perspective on the dataset.
#
# The paper demonstrated the importance of graphs in analysisng data in conjunction with numeric data.
#
# "A computer should make both calculations and graphs. Both sorts of output should be studied;
# each will contribute to understanding."
#
# Francis J. Anscombe was an English statistician educated at Cambridge University.

# %% [markdown]
# ### Summary Statistics

# %%
import pandas as pd

# %%
df = pd.read_csv("https://web.stanford.edu/class/cs102/datasets/Anscombe.csv")

# %%
df
# Out:
#     X1     Y1  X2    Y2  X3     Y3  X4     Y4  Unnamed: 8  Unnamed: 9  \
# 0   10   8.04  10  9.14  10   7.46   8   6.58         NaN         NaN
# 1    8   6.95   8  8.14   8   6.77   8   5.76         NaN         NaN
# 2   13   7.58  13  8.74  13  12.74   8   7.71         NaN         NaN
# 3    9   8.81   9  8.77   9   7.11   8   8.84         NaN         NaN
# 4   11   8.33  11  9.26  11   7.81   8   8.47         NaN         NaN
# 5   14   9.96  14  8.10  14   8.84   8   7.04         NaN         NaN
# 6    6   7.24   6  6.13   6   6.08   8   5.25         NaN         NaN
# 7    4   4.26   4  3.10   4   5.39  19  12.50         NaN         NaN
# 8   12  10.84  12  9.13  12   8.15   8   5.56         NaN         NaN
# 9    7   4.82   7  7.26   7   6.42   8   7.91         NaN         NaN
# 10   5   5.68   5  4.74   5   5.73   8   6.89         NaN         NaN
#
#        ...       Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# ...

# %%
df2= pd.read_csv("https://web.stanford.edu/class/cs102/datasets/Anscombe.csv",usecols = ['X1','Y1','X2','Y2','X3','Y3','X4','Y4'])

# %%
df2
# Out:
#     X1     Y1  X2    Y2  X3     Y3  X4     Y4
# 0   10   8.04  10  9.14  10   7.46   8   6.58
# 1    8   6.95   8  8.14   8   6.77   8   5.76
# 2   13   7.58  13  8.74  13  12.74   8   7.71
# 3    9   8.81   9  8.77   9   7.11   8   8.84
# 4   11   8.33  11  9.26  11   7.81   8   8.47
# 5   14   9.96  14  8.10  14   8.84   8   7.04
# 6    6   7.24   6  6.13   6   6.08   8   5.25
# 7    4   4.26   4  3.10   4   5.39  19  12.50
# 8   12  10.84  12  9.13  12   8.15   8   5.56
# 9    7   4.82   7  7.26   7   6.42   8   7.91
# 10   5   5.68   5  4.74   5   5.73   8   6.89

# %%
df2.describe()
# Out:
#               X1         Y1         X2         Y2         X3         Y3  \
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   7.500909   9.000000   7.500909   9.000000   7.500000
# std     3.316625   2.031568   3.316625   2.031657   3.316625   2.030424
# min     4.000000   4.260000   4.000000   3.100000   4.000000   5.390000
# 25%     6.500000   6.315000   6.500000   6.695000   6.500000   6.250000
# 50%     9.000000   7.580000   9.000000   8.140000   9.000000   7.110000
# 75%    11.500000   8.570000  11.500000   8.950000  11.500000   7.980000
# max    14.000000  10.840000  14.000000   9.260000  14.000000  12.740000
#
#               X4         Y4
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %%
import seaborn as sns

# %%
sns.pairplot(df2.iloc[:,[0,1]])
